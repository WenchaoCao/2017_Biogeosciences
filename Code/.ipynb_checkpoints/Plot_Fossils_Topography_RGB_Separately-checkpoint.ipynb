# %% [markdown]
# # Materials associated with the paper:
#
# Cao, W., Zahirovic, S., Flament, N., Williams, S., Golonka, J., and Müller, R. D., 2017: Improving global paleogeography since the late Paleozoic using paleobiology, Biogeosciences, 14, 5425-5439. https://doi.org/10.5194/bg-14-5425-2017.
#
# ### This Jupyter notebook aims to plot palebiological data sets on present-day global toporaphic maps
#
# The code in this notebook is written in Python 2.7. It utilizes standard scientific Python modules as well as modules from the open source pygplates which provides a Python API to the open source GPlates software (https://www.gplates.org/).

# %%
# %matplotlib inline
from mpl_toolkits.basemap import Basemap
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt
import pandas as pd    
from matplotlib import colors
from matplotlib import legend

#pandas can read anything, in contrast, numpy just can read numbers but not characters
Fossil_data=pd.read_csv('../Data/Fossil_Collections_Genus_PBDB_2500_0Ma/2500Ma-collections.csv', delimiter=',')  
#av_age = (Fossil_data.ma_max+Fossil_data.ma_min)/2
Fossil_data
# Out:
#        collection_no collection.authorizer license  collection.reference_no  \
# 0                184             A. Miller   CC BY                       13
# 1                186           J. Sepkoski   CC BY                       13
# 2                187           J. Sepkoski   CC BY                       13
# 3                189           J. Sepkoski   CC BY                       13
# 4                193           J. Sepkoski   CC BY                       13
# 5                196           J. Sepkoski   CC BY                       13
# 6                201           J. Sepkoski   CC BY                       13
# 7                202           J. Sepkoski   CC BY                       13
# 8                203           J. Sepkoski   CC BY                    51517
# 9                208           J. Sepkoski   CC BY                       13
# 10               209           J. Sepkoski   CC BY                       13
# 11               216           J. Sepkoski   CC BY                       13
# 12               220           J. Sepkoski   CC BY                    16657
# 13               223           J. Sepkoski   CC BY                       13
# 14               224           J. Sepkoski   CC BY                       13
# 15               227           J. Sepkoski   CC BY                       13
# 16               228           J. Sepkoski   CC BY                    26476
# 17               232           J. Sepkoski   CC BY                    32153
# 18               233           J. Sepkoski   CC BY                       13
# 19               237           J. Sepkoski   CC BY                       13
# 20               240           J. Sepkoski   CC BY                       13
# 21               241           J. Sepkoski   CC BY                       13
# 22               242           J. Sepkoski   CC BY                       13
# 23               243           J. Sepkoski   CC BY                       13
# 24               244           J. Sepkoski   CC BY                       13
# 25               245           J. Sepkoski   CC BY                       13
# 26               246           J. Sepkoski   CC BY                       13
# 27               247           J. Sepkoski   CC BY                       13
# 28               249           J. Sepkoski   CC BY                       13
# 29               252           J. Sepkoski   CC BY                       13
# ...              ...                   ...     ...                      ...
# 77845         180995            P. Holroyd   CC BY                    60102
# 77846         181024            P. Holroyd   CC BY                    60112
# 77847         181030            P. Holroyd   CC BY                    59665
# 77848         181031            P. Holroyd   CC BY                    60117
# 77849         181052            P. Mannion   CC BY                    60127
# 77850         181053            P. Mannion   CC BY                    60127
# 77851         181055            P. Barrett   CC BY                    60132
# 77852         181059            M. Carrano   CC BY                    60138
# 77853         181065            A. McGowan   CC BY                    60143
# 77854         181066            A. McGowan   CC BY                    60143
# 77855         181067            A. McGowan   CC BY                    60143
# 77856         181069            A. McGowan   CC BY                    60146
# 77857         181070            A. McGowan   CC BY                    60147
# 77858         181071            P. Barrett   CC BY                    60149
# 77859         181073            M. Clapham   CC BY                    60151
# 77860         181080            M. Clapham   CC BY                    60157
# 77861         181081            A. McGowan   CC BY                    60158
# 77862         181254            P. Mannion   CC BY                    60256
# 77863         181255               M. Uhen   CC BY                    60257
# 77864         181304            P. Mannion   CC BY                    60274
# 77865         181305              D. Perez   CC BY                    60281
# 77866         181306               M. Uhen   CC BY                    60282
# 77867         181308           A. Stafford   CC BY                    60286
# 77868         181311            P. Barrett   CC BY                    60289
# 77869         181312               M. Uhen   CC BY                    60293
# 77870         181313            P. Barrett   CC BY                    60296
# 77871         181314               M. Uhen   CC BY                    60285
# 77872         181316       N. Ochsenknecht   CC BY                    60259
# 77873         181318               M. Uhen   CC BY                    60302
# 77874         181322               M. Uhen   CC BY                    60306
#
#           latdec      lngdec      period                   epoch  \
# 0      79.130000  -76.000000    Cambrian    Early/Lower Cambrian
# 1      52.833333 -119.250000    Cambrian                     NaN
# 2      52.833333 -119.250000    Cambrian         Middle Cambrian
# 3      42.410556  -73.525000    Cambrian    Early/Lower Cambrian
# 4      65.000000 -111.500000    Cambrian    Early/Lower Cambrian
# 5      52.833333 -119.250000    Cambrian    Early/Lower Cambrian
# 6      39.163889 -119.833056    Cambrian    Early/Lower Cambrian
# 7      39.163889 -119.833056    Cambrian    Early/Lower Cambrian
# 8     -19.629167  136.916667    Cambrian    Early/Lower Cambrian
# 9      38.868889 -117.921111    Cambrian               Furongian
# 10     65.000000 -111.500000    Cambrian         Middle Cambrian
# 11     39.359722 -111.585556    Cambrian         Middle Cambrian
# 12     35.991944 -113.816389    Cambrian         Middle Cambrian
# 13     44.368333 -100.350556    Cambrian               Furongian
# 14     44.662222 -111.103333    Cambrian               Furongian
# 15     44.662222 -111.103333    Cambrian               Furongian
# 16     30.034722 -103.308333    Cambrian                     NaN
# 17     39.644444  -86.864722    Cambrian               Furongian
# 18     44.662222 -111.103333    Cambrian               Furongian
# 19     30.205000 -103.244167    Cambrian                     NaN
# 20     36.175000 -115.136389    Cambrian               Furongian
# 21     36.175000 -115.136389    Cambrian               Furongian
# 22     47.153611 -110.215556    Cambrian               Furongian
# 23     47.153611 -110.215556    Cambrian               Furongian
# 24     47.416667 -105.591667    Cambrian               Furongian
# 25     39.644444  -86.864722    Cambrian               Furongian
# 26     47.416667 -105.591667    Cambrian               Furongian
# 27     47.153611 -110.215556    Cambrian               Furongian
# 28     47.153611 -110.215556    Cambrian               Furongian
# 29     38.563889 -116.425833    Cambrian               Furongian
# ...          ...         ...         ...                     ...
# 77845 -46.870000  169.222400   Paleogene               Oligocene
# 77846  49.600000 -111.000000  Cretaceous   Late/Upper Cretaceous
# 77847  45.900000   23.200000  Cretaceous   Late/Upper Cretaceous
# 77848  42.829444   -3.542500  Cretaceous   Late/Upper Cretaceous
# 77849  23.538611  -15.928056   Paleogene               Oligocene
# 77850  23.488333  -15.952778   Paleogene               Oligocene
# 77851 -28.470000  138.250000   Paleogene               Oligocene
# 77852 -50.269167  -72.044167  Cretaceous   Late/Upper Cretaceous
# 77853  57.683500   -6.348900    Jurassic         Middle Jurassic
# 77854  57.683500   -6.348900    Jurassic         Middle Jurassic
# 77855  57.683500   -6.348900    Jurassic         Middle Jurassic
# 77856  55.297112   -4.757962  Ordovician   Late/Upper Ordovician
# 77857  57.172028   -6.106008    Jurassic         Middle Jurassic
# 77858  49.933333    8.750000   Paleogene                  Eocene
# 77859  48.720000    3.720000   Paleogene               Paleocene
# 77860  41.205000  119.250000  Cretaceous  Early/Lower Cretaceous
# 77861  56.373887   -3.434477    Devonian    Early/Lower Devonian
# 77862  30.905000   -3.855000  Cretaceous                     NaN
# 77863  42.812124 -114.898669     Neogene                Pliocene
# 77864  16.079444  -91.067500     Neogene                     NaN
# 77865 -37.354500  140.796120  Quaternary             Pleistocene
# 77866 -19.232152  145.418174  Quaternary                     NaN
# 77867 -29.666900  140.939000  Quaternary             Pleistocene
# 77868  49.933300    8.733300   Paleogene                  Eocene
# 77869 -37.280000  144.730000  Quaternary             Pleistocene
# 77870  41.700000 -109.000000   Paleogene                  Eocene
# 77871 -35.983333  137.050000  Quaternary             Pleistocene
# 77872 -40.882960  145.147360     Neogene                 Miocene
# 77873 -28.000000  138.000000         NaN                     NaN
# 77874 -34.306670  115.145280  Quaternary             Pleistocene
#
#                         stage   ma_max    ma_min  \
# 0                         NaN  530.000  513.0000
# 1                         NaN  541.000  485.4000
# 2                         NaN  513.000  505.0000
# 3                         NaN  516.000  513.0000
# 4                         NaN  530.000  513.0000
# 5                         NaN  516.000  513.0000
# 6                         NaN  516.000  513.0000
# 7                         NaN  516.000  513.0000
# 8                         NaN  516.000  513.0000
# 9                         NaN  501.000  485.4000
# 10                        NaN  513.000  501.0000
# 11                        NaN  513.000  501.0000
# 12                        NaN  513.000  501.0000
# 13                        NaN  501.000  485.4000
# 14                        NaN  501.000  485.4000
# 15                        NaN  501.000  485.4000
# 16                        NaN  513.000  498.5000
# 17                        NaN  501.000  485.4000
# 18                        NaN  501.000  485.4000
# 19                        NaN  541.000  485.4000
# 20                        NaN  501.000  485.4000
# 21                        NaN  501.000  485.4000
# 22                        NaN  501.000  485.4000
# 23                        NaN  501.000  485.4000
# 24                        NaN  501.000  485.4000
# 25                        NaN  501.000  485.4000
# 26                        NaN  501.000  485.4000
# 27                        NaN  501.000  485.4000
# 28                        NaN  501.000  485.4000
# 29                        NaN  501.000  485.4000
# ...                       ...      ...       ...
# 77845                Chattian   28.400   23.0300
# 77846               Campanian   83.500   70.6000
# 77847           Maastrichtian   72.100   66.0000
# 77848           Maastrichtian   72.100   66.0000
# 77849                Rupelian   33.900   28.4000
# 77850                Rupelian   33.900   28.4000
# 77851                Chattian   28.400   23.0300
# 77852           Maastrichtian   70.600   66.0000
# 77853               Bathonian  168.300  166.1000
# 77854               Bathonian  168.300  166.1000
# 77855               Bathonian  168.300  166.1000
# 77856  middle Late Ordovician  453.000  445.2000
# 77857               Bathonian  168.300  166.1000
# 77858                Lutetian   48.600   40.4000
# 77859               Thanetian   59.200   56.0000
# 77860                  Aptian  125.450  122.4600
# 77861                 Pragian  410.800  407.6000
# 77862                     NaN  105.300   93.5000
# 77863                     NaN    5.333    2.5880
# 77864                     NaN   10.300    4.9000
# 77865                     NaN    2.588    0.0117
# 77866                     NaN    0.126    0.0000
# 77867                     NaN    0.126    0.0117
# 77868                Lutetian   48.600   40.4000
# 77869                     NaN    0.126    0.0117
# 77870                Ypresian   55.800   50.3000
# 77871                     NaN    0.126    0.0117
# 77872                     NaN   23.030   15.9700
# 77873                     NaN   28.400   15.9700
# 77874                     NaN    2.588    0.7810
#
#                             lithology1    lithology2  \
# 0                          "limestone"           NaN
# 1                          "limestone"           NaN
# 2                          "limestone"           NaN
# 3                          "limestone"       "shale"
# 4                          "limestone"       "shale"
# 5                          "limestone"           NaN
# 6                          "limestone"           NaN
# 7                          "limestone"           NaN
# 8                           wackestone           NaN
# 9                         conglomerate           NaN
# 10                         "carbonate"       "shale"
# 11                             "shale"           NaN
# 12                         "limestone"           NaN
# 13                           sandstone           NaN
# 14                         "limestone"           NaN
# 15                         "limestone"           NaN
# 16                         "limestone"       "shale"
# 17                         "carbonate"           NaN
# 18                         "carbonate"           NaN
# 19                        conglomerate           NaN
# 20                         "carbonate"           NaN
# 21                         "carbonate"           NaN
# 22                                 NaN           NaN
# 23                             "shale"           NaN
# 24                                 NaN           NaN
# 25                         "limestone"           NaN
# 26                                 NaN           NaN
# 27                         "limestone"           NaN
# 28                         "limestone"           NaN
# 29                          wackestone           NaN
# ...                                ...           ...
# 77845                         mudstone           NaN
# 77846                        siltstone           NaN
# 77847                        sandstone           NaN
# 77848                             marl           NaN
# 77849                     conglomerate           NaN
# 77850                     conglomerate           NaN
# 77851                        siltstone     claystone
# 77852                        sandstone  conglomerate
# 77853                        sandstone           NaN
# 77854                    lime mudstone           NaN
# 77855                        sandstone           NaN
# 77856                        siltstone           NaN
# 77857  "mixed carbonate-siliciclastic"           NaN
# 77858                        claystone           NaN
# 77859                       travertine           NaN
# 77860                         mudstone           NaN
# 77861                         mudstone           NaN
# 77862                        sandstone           NaN
# 77863                     not reported           NaN
# 77864                        sandstone           NaN
# 77865                        claystone           NaN
# 77866                     not reported           NaN
# 77867                         mudstone           NaN
# 77868                          "shale"           NaN
# 77869                     not reported           NaN
# 77870                        siltstone     sandstone
# 77871                     not reported           NaN
# 77872                     not reported           NaN
# 77873                        claystone           NaN
# 77874                     not reported           NaN
#
#                                 environment tectonic_setting  \
# 0                                 peritidal              NaN
# 1                  reef, buildup or bioherm              NaN
# 2                  reef, buildup or bioherm              NaN
# 3                            offshore shelf              NaN
# 4                                     slope              NaN
# 5                  reef, buildup or bioherm              NaN
# 6                                sand shoal              NaN
# 7                  reef, buildup or bioherm              NaN
# 8                  reef, buildup or bioherm              NaN
# 9                            offshore shelf              NaN
# 10                                    slope              NaN
# 11                           offshore shelf              NaN
# 12                                 offshore              NaN
# 13                                 lagoonal   cratonic basin
# 14                  shallow subtidal indet.   cratonic basin
# 15                                 lagoonal   cratonic basin
# 16                           offshore shelf              NaN
# 17                               sand shoal   cratonic basin
# 18                               sand shoal   cratonic basin
# 19                           offshore shelf              NaN
# 20                  shallow subtidal indet.              NaN
# 21                      deep subtidal shelf              NaN
# 22                 reef, buildup or bioherm   cratonic basin
# 23                                 lagoonal   cratonic basin
# 24                                 lagoonal   cratonic basin
# 25                  shallow subtidal indet.   cratonic basin
# 26                                 lagoonal   cratonic basin
# 27                  shallow subtidal indet.   cratonic basin
# 28                  shallow subtidal indet.   cratonic basin
# 29                                    slope              NaN
# ...                                     ...              ...
# 77845                           estuary/bay              NaN
# 77846                        fluvial indet.              NaN
# 77847                                  pond              NaN
# 77848                     lacustrine indet.              NaN
# 77849                           estuary/bay              NaN
# 77850                           estuary/bay              NaN
# 77851             fluvial-lacustrine_indet.              NaN
# 77852       transition zone/lower shoreface              NaN
# 77853                           delta plain              NaN
# 77854                              lagoonal              NaN
# 77855                              lagoonal              NaN
# 77856                       offshore indet.              NaN
# 77857  lagoonal/restricted shallow subtidal              NaN
# 77858                           crater lake   volcanic basin
# 77859                                spring   cratonic basin
# 77860                    lacustrine - large             rift
# 77861             fluvial-lacustrine_indet.              NaN
# 77862                             "channel"              NaN
# 77863                          "floodplain"              NaN
# 77864                              lagoonal              NaN
# 77865                                  cave              NaN
# 77866                                  cave              NaN
# 77867             fluvial-lacustrine_indet.              NaN
# 77868                     lacustrine indet.              NaN
# 77869                            mire/swamp              NaN
# 77870                           channel lag              NaN
# 77871                                  cave              NaN
# 77872                            mire/swamp              NaN
# 77873                    lacustrine - large              NaN
# 77874                        coastal indet.              NaN
#
#                                         geology_comments
# 0      "thin bedded, glauconitic, arenaceous lst. gre...
# 1      "oolitic, sandly ls, thick bedded, carbonate b...
# 2      "ls, partially x-bedded; some intraformational...
# 3      "sh and ls; ls beds up to 15 cm thick, fine gr...
# 4      "calcareous sh and silty ls. 'basin facies' -u...
# 5      "platy ls, argillaceous, some oolite, carbonat...
# 6      "argillaceous fine grained ls, back-bank, inne...
# 7      "coarse bioclastic limestone, shoal water carb...
# 8                         "oolitic and xtalline ls, BA3"
# 9             "gravity-flow ls. congl. outer shelf, BA5"
# 10     "nodular calcareous sh with minor silty dolomi...
# 11     "ocean facing shelf, below wave base (BA5). no...
# 12                      "mottled ls, offshore bank, BA3"
# 13     "nearshore lagoons and embayments, BA1. craton...
# 14     "ribboned ls. very shallow subtidal to lowest ...
# 15     "intercalated thin-bedded shale, limestone and...
# 16     "ls. boulders in dark green shale. outer shelf...
# 17     "oolite. shallow oolite shoal, correlative wit...
# 18     "oolite and assoc carbonates, offshore oolite ...
# 19     "ls boulders in dark greenish clay shale, oute...
# 20     "shoaling shelf community, carbonate (silty wa...
# 21     "carbonate (wackestones and packstones), ocean...
# 22     "Stromatolite bioherm (Collenia magna) Communi...
# 23     "Below Collenia magna bioherms, subtidal shelf...
# 24     "sh, ls and congl. muddy shelf lagoon. BA2. cr...
# 25     "silty to fine-sandy ls (5' interval), shallow...
# 26     "Sh, ls, and congl. muddy shelf lagoon, BA2, c...
# 27     "sh and flat pebble congl, shallow subtidal sh...
# 28     "sh and flat-pebble congl., shallow subtidal s...
# 29     "outer detrital belt, dark fine grained ls (mu...
# ...                                                  ...
# 77845                                                NaN
# 77846                                                NaN
# 77847                                                NaN
# 77848  Lacustrine environment with varying oxygen levels
# 77849                                                NaN
# 77850                                                NaN
# 77851  "These units represent lacustrine deposits int...
# 77852  "inter- to subtidal deposits under an estuarin...
# 77853              Lithofacies 4 is a prograding delta.
# 77854  Lithofacies 4 is interpreted as having been de...
# 77855   Lithofacies 1 is a prograding delta environment.
# 77856  Deeper-water downslope setting in a steep, nar...
# 77857  A shallow ephemeral lagoonal environment fed b...
# 77858  "A drilling project conducted in 2001 showed t...
# 77859                                                NaN
# 77860                                                NaN
# 77861  Mudstones and siltstones indicate deposition i...
# 77862                                                NaN
# 77863  Hagerman�s depositional environment  is interp...
# 77864                coastal lagoon or overbank deposits
# 77865                                                NaN
# 77866                                                NaN
# 77867                                                NaN
# 77868  finely laminated sediments laid down in a smal...
# 77869                                                NaN
# 77870                                                NaN
# 77871                                                NaN
# 77872                                                NaN
# 77873                                                NaN
# 77874                                                NaN
#
# [77875 rows x 16 columns]

# %%
# create new figure, set the figure size
#fig = plt.subplots(3, 3)
fig=plt.figure(figsize=(8,5.5),tight_layout=True)  #fig=plt.figure(figsize=(8.27, 11.69)) 

# The first plot
sub1 = fig.add_subplot(331)
#resolution: c (crude), l (low), i (intermediate), h (high), f (full) or None
m = Basemap(projection='moll',lat_0=0,lon_0=0, resolution='c')
# display a non-default image.
m.warpimage(image='../Data/ETOPO/etopo_greyscale.jpg',alpha=0.6,scale=0.25)
# draw lat/lon grid lines every 30 degrees.
#m.drawmeridians(np.arange(0,360,30),color='0.5')
#m.drawparallels(np.arange(-90,90,30),color='0.5')
df = Fossil_data.dropna(subset = ['period'])
subset1 = df[df['period'].str.contains('Devonian')]
x,y = m(np.asarray(subset1.lngdec),np.asarray(subset1.latdec))
sub1 = sub1.plot(x,y,'o',color=[203./255.,140./255.,55./255.],markeredgecolor='white',markersize=2, markeredgewidth=0.2 )
plt.title('Devonian', fontsize=14)
plt.xlabel('N=%d' % (len(subset1)+1), fontsize=10)

#second plots
sub2 = fig.add_subplot(332)
m = Basemap(projection='moll',lat_0=0,lon_0=0, resolution='c')
m.warpimage(image='../Data/ETOPO/etopo_greyscale.jpg',alpha=0.6,scale=0.25)
df = Fossil_data.dropna(subset = ['period'])
subset2 = df[df['period'].str.contains('Carboniferous')]
x,y = m(np.asarray(subset2.lngdec),np.asarray(subset2.latdec))
sub2 = plt.plot(x,y,'o',color=[103./255.,165./255.,153./255.],markeredgecolor='white',markersize=2, markeredgewidth=0.2)
#m.drawmeridians(np.arange(0,360,30),color='0.5')
#m.drawparallels(np.arange(-90,90,30),color='0.5')
plt.title('Carboniferous', fontsize=14)
plt.xlabel('N=%d' % (len(subset2)+1), fontsize=10)

#Third plots
sub3 = fig.add_subplot(333)
m = Basemap(projection='moll',lat_0=0,lon_0=0, resolution='c')
m.warpimage(image='../Data/ETOPO/etopo_greyscale.jpg',alpha=0.6,scale=0.25)
df = Fossil_data.dropna(subset = ['period'])
subset3 = df[df['period'].str.contains('Permian')]
x,y = m(np.asarray(subset3.lngdec),np.asarray(subset3.latdec))
sub3 = plt.plot(x,y,'o',color=[240./255.,64./255.,40./255.],markeredgecolor='white',markersize=2, markeredgewidth=0.2)
#m.drawmeridians(np.arange(0,360,30),color='0.5')
#m.drawparallels(np.arange(-90,90,30),color='0.5')
plt.title('Permian', fontsize=14)
plt.xlabel('N=%d' % (len(subset3)+1), fontsize=10)

# plots 4
sub3 = fig.add_subplot(334)
m = Basemap(projection='moll',lat_0=0,lon_0=0, resolution='c')
m.warpimage(image='../Data/ETOPO/etopo_greyscale.jpg',alpha=0.6,scale=0.25)
df = Fossil_data.dropna(subset = ['period'])
subset4 = df[df['period'].str.contains('Triassic')]
x,y = m(np.asarray(subset4.lngdec),np.asarray(subset4.latdec))
sub4 = plt.plot(x,y,'o',color=[129./255.,43./255.,146./255.],markeredgecolor='white',markersize=2, markeredgewidth=0.2)
#m.drawmeridians(np.arange(0,360,30),color='0.5')
#m.drawparallels(np.arange(-90,90,30),color='0.5')
plt.title('Triassic', fontsize=14)
plt.xlabel('N=%d' % (len(subset4)+1), fontsize=10)

#plots 5
sub3 = fig.add_subplot(335)
m = Basemap(projection='moll',lat_0=0,lon_0=0, resolution='c')
m.warpimage(image='../Data/ETOPO/etopo_greyscale.jpg',alpha=0.6,scale=0.25)
df = Fossil_data.dropna(subset = ['period'])
subset5 = df[df['period'].str.contains('Jurassic')]
x,y = m(np.asarray(subset5.lngdec),np.asarray(subset5.latdec))
sub5 = plt.plot(x,y,'o',color=[52./255.,178./255.,201./255.],markeredgecolor='white',markersize=2, markeredgewidth=0.2)
#m.drawmeridians(np.arange(0,360,30),color='0.5')
#m.drawparallels(np.arange(-90,90,30),color='0.5')
plt.title('Jurassic', fontsize=14)
plt.xlabel('N=%d' % (len(subset5)+1), fontsize=10)

#plot 6
sub3 = fig.add_subplot(336)
m = Basemap(projection='moll',lat_0=0,lon_0=0, resolution='c')
m.warpimage(image='../Data/ETOPO/etopo_greyscale.jpg',alpha=0.6,scale=0.25)
df = Fossil_data.dropna(subset = ['period'])
subset6 = df[df['period'].str.contains('Cretaceous')]
x,y = m(np.asarray(subset6.lngdec),np.asarray(subset6.latdec))
sub6 = plt.plot(x,y,'o',color=[127./255.,198./255.,78./255.],markeredgecolor='white',markersize=2, markeredgewidth=0.2)
#m.drawmeridians(np.arange(0,360,30),color='0.5')
#m.drawparallels(np.arange(-90,90,30),color='0.5')
plt.title('Cretaceous', fontsize=14)
plt.xlabel('N=%d' % (len(subset6)+1), fontsize=10)

#plot 7
sub3 = fig.add_subplot(337)
m = Basemap(projection='moll',lat_0=0,lon_0=0, resolution='c')
m.warpimage(image='../Data/ETOPO/etopo_greyscale.jpg',alpha=0.6,scale=0.25)
df = Fossil_data.dropna(subset = ['period'])
subset7 = df[df['period'].str.contains('Paleogene')]
x,y = m(np.asarray(subset7.lngdec),np.asarray(subset7.latdec))
sub7 = plt.plot(x,y,'o',color=[253./255.,154./255.,82./255.],markeredgecolor='white',markersize=2, markeredgewidth=0.2)
#m.drawmeridians(np.arange(0,360,30),color='0.5')
#m.drawparallels(np.arange(-90,90,30),color='0.5')
plt.title('Paleogene', fontsize=14)
plt.xlabel('N=%d' % (len(subset7)+1), fontsize=10)

#plot 8
sub3 = fig.add_subplot(338)
m = Basemap(projection='moll',lat_0=0,lon_0=0, resolution='c')
m.warpimage(image='../Data/ETOPO/etopo_greyscale.jpg',alpha=0.6,scale=0.25)
df = Fossil_data.dropna(subset = ['period'])
subset8 = df[df['period'].str.contains('Neogene')]
x,y = m(np.asarray(subset8.lngdec),np.asarray(subset8.latdec))
sub8 = plt.plot(x,y,'o',color=[255./255.,230./255.,25./255.],markeredgecolor='white',markersize=2, markeredgewidth=0.2)
#m.drawmeridians(np.arange(0,360,30),color='0.5')
#m.drawparallels(np.arange(-90,90,30),color='0.5')
plt.title('Neogene', fontsize=14)
plt.xlabel('N=%d' % (len(subset8)+1), fontsize=10)

#plot 9
sub3 = fig.add_subplot(339)
m = Basemap(projection='moll',lat_0=0,lon_0=0, resolution='c')
m.warpimage(image='../Data/ETOPO/etopo_greyscale.jpg',alpha=0.6,scale=0.25)
df = Fossil_data.dropna(subset = ['period'])
subset9 = df[df['period'].str.contains('Quaternary')]
x,y = m(np.asarray(subset9.lngdec),np.asarray(subset9.latdec))
sub9 = plt.plot(x,y,'o',color=[249./255.,249./255.,127./255.],markeredgecolor='white',markersize=2, markeredgewidth=0.2)
#m.drawmeridians(np.arange(0,360,30),color='0.5')
#m.drawparallels(np.arange(-90,90,30),color='0.5')
plt.title('Quaternary', fontsize=14)
plt.xlabel('N=%d' % (len(subset9)+1), fontsize=10)
#plt.(0.5, 1.08, "Number= 2338",horizontalalignment='bottom',fontsize=10)

plt.savefig('../Code/Output/Fossils_Coverage_Separately.pdf',dpi=600)
plt.tight_layout()
plt.show()
