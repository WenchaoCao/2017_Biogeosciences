# %%
% matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#data
Areas_Lands = pd.read_csv('/Users/wenchaocao/Research/8_FloodingHistory_410_2Ma/4_Areas_ReconsPaleogeog_EBIDs_AfterModifiedByFossils_402-2Ma/Areas_Paleogeog_Features_latest.csv', delimiter=',')  
#Areas_Lands
#Fossil_data['Time intervals']
#Fossil_data.icesheet

# %%
plt.figure(figsize=(8,5)) #figsize=(12,8)
plot = plt.plot(Areas_Lands['Time intervals'],Areas_Lands['A_E-Land (Al+Amo+Ai)'],'red',
         Areas_Lands['Time intervals'], Areas_Lands['A_T-Land (Al+Amo+Ai+Ama)'],'green', 
         Areas_Lands['Time intervals'], Areas_Lands['Aocean (A_E - A_T-Land)'],'blue')

# x, y labels, ticks, scales, line width and so on
plt.xlabel('Time(Ma)', fontsize=16)
# np.hstack: Take a sequence of arrays and stack them horizontally to make a single array. eg. np.hstack((a,b))
plt.xticks(np.hstack((Areas_Lands['Time intervals'][0],Areas_Lands['Time intervals'][1::2])), size=10, rotation=50) #
plt.ylabel('Areas of total land, emerged land and deep ocean (x10^7 sq.km)', fontsize=14)
plt.xlim((402,0))
plt.ylim() #(0,40)
plt.setp(plot, linewidth=1.5)
plt.legend(('Emerged land','Total land','Deep ocean'),bbox_to_anchor=(.05,.7), loc=2, borderaxespad=0.)
plt.grid()
plt.show
plt.savefig('areas_features.pdf',dpi=600)
plt.savefig('areas_features.ps',dpi=600)
plt.savefig('areas_features.png',dpi=600)

# %%
plt.figure(figsize=(8,5)) #figsize=(12,8)
fig, ax = plt.subplots(figsize=(8,5))

ax.plot(Areas_Lands['Time intervals'],Areas_Lands['A_E-Land (Al+Amo+Ai)']/51*100,'red',
         Areas_Lands['Time intervals'], Areas_Lands['A_T-Land (Al+Amo+Ai+Ama)']/51*100,'blue', linewidth=1.5)

# x, y labels, ticks, scales, line width and so on
ax.set_xlabel('Time (Ma)', fontsize=14)
# np.hstack: Take a sequence of arrays and stack them horizontally to make a single array. eg. np.hstack((a,b))
ax.set_xticks(np.hstack((Areas_Lands['Time intervals'][0],Areas_Lands['Time intervals'][1::2]))) #, rotation=50
ax.xaxis.set_tick_params(labelsize=10,direction='out')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=50)
ax.xaxis.set_label_position('bottom')
ax.xaxis.set_ticks_position('bottom')
ax.set_xlim((402,2))
ax.yaxis.set_tick_params(labelsize=12,direction='out')
ax.yaxis.set_ticks_position('left')
ax.set_ylabel('Areas of total land and emerged land [% Earth surface]',fontsize=12)
ax.set_ylim((20, 45)) #(0,40)
ax.grid()

plt.legend(('Emerged land','Total land'),bbox_to_anchor=(0.75,.65), loc=2, borderaxespad=0., fontsize=10)

plt.show
plt.savefig('percentages_TLand_ELand.pdf',dpi=600)
plt.savefig('percentages_TLand_ELand.png',dpi=600)
plt.savefig('percentages_TLand_ELand.ps',dpi=600)

print min(Areas_Lands['A_E-Land (Al+Amo+Ai)']/51*100)
print max(Areas_Lands['A_E-Land (Al+Amo+Ai)']/51*100)
print np.mean(Areas_Lands['A_E-Land (Al+Amo+Ai)']/51*100)
# Out:
# 20.431372549
# 29.8823529412
# 25.7018055556

# %%
% matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(16,6)) #figsize=(12,8)
fig, ax1 = plt.subplots(figsize=(10,5))

ax1.plot(Areas_Lands['Time intervals'],Areas_Lands['A_E-Land (Al+Amo+Ai)']/51*100,'red',
         Areas_Lands['Time intervals'], Areas_Lands['A_T-Land (Al+Amo+Ai+Ama)']/51*100,'blue', linewidth=1.5) #/51*100
ax1.plot(Areas_Lands['Time intervals'], Areas_Lands['Area_sm']/51*100,'green', linewidth=1.5)

# x, y labels, ticks, scales, line width and so on
ax1.set_xlabel('Time (Ma)', fontsize=14)
# np.hstack: Take a sequence of arrays and stack them horizontally to make a single array. eg. np.hstack((a,b))
ax1.set_xticks(np.hstack((Areas_Lands['Time intervals'][0],Areas_Lands['Time intervals'][1::2]))) #, rotation=50
ax1.xaxis.set_tick_params(labelsize=10,direction='out')
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=50)
ax1.xaxis.set_label_position('bottom')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_xlim((2,402))
ax1.yaxis.set_tick_params(labelsize=12,direction='out')
ax1.yaxis.set_ticks_position('left')
ax1.set_ylabel('Areas of total land and emerged land [% Earth surface]',fontsize=12)
#ax1.set_ylim((20, 45)) #(0,40)
ax1.grid()


ax2 = ax1.twinx()


Sr_data = pd.read_csv('/Users/wenchaocao/Research/34_Paper_Biogeosciences/Nico_data/sr-data-last-402Ma.dat', delimiter=' ')
Sr_data['Time']
Sr_data['Values']
ax2.scatter(Sr_data['Time'], Sr_data['Values'],s=40, marker='o', color='lightgrey', edgecolors='darkgrey',alpha=0.5) #s=10, edgecolors='none'
ax2.set_xlim((2,402))
ax2.set_ylim((0.7096,0.7065))
ax2.set_ylabel(r'$^8$'r'$^7$''Sr/'r'$^8$'r'$^6$''Sr',fontsize=16)
#plt.xticks(size=12)
#plt.yticks(size=12)

pos1 = ax1.get_position()
ax1.set_position(ax2.get_position())
ax2.set_position(pos1)
#plt.legend(('Emerged land','Total land'),bbox_to_anchor=(0.75,.65), loc=2, borderaxespad=0., fontsize=10)

#plt.show
#plt.savefig('percentages_TLand_ELand.pdf',dpi=600)
#plt.savefig('percentages_TLand_ELand.png',dpi=600)
#plt.savefig('percentages_TLand_ELand.ps',dpi=600)

#print min(Areas_Lands['A_E-Land (Al+Amo+Ai)']/51*100)
#print max(Areas_Lands['A_E-Land (Al+Amo+Ai)']/51*100)
#print np.mean(Areas_Lands['A_E-Land (Al+Amo+Ai)']/51*100)

#plt.savefig('Sr_data.pdf',dpi=600)
#plt.savefig('Sr_data.png',dpi=600)
#plt.savefig('Sr_data.ps',dpi=600)

# %%
% matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#plt.figure() #figsize=(12,8)
fig, ax1 = plt.subplots(figsize=(8,5))

Sr_data = pd.read_csv('/Users/wenchaocao/Research/34_Paper_Biogeosciences/Nico_data/Dataset.csv')
#Sr_data = pd.read_csv('/Users/wenchaocao/Research/34_Paper_Biogeosciences/Nico_data/sr-data-last-402Ma.dat', delimiter=' ')
Sr_data['Time']
Sr_data['Values']
#ax1.scatter(Sr_data['Time'], Sr_data['Values'],s=40, marker='o', color='lightgrey', edgecolors='grey',alpha=1.)
ax1.plot(Sr_data['Time'], Sr_data['Values'],'green', linewidth=1.5)

# set x axis
ax1.set_xticks(np.hstack((Areas_Lands['Time intervals'][0],Areas_Lands['Time intervals'][1::2]))) #, rotation=50
ax1.xaxis.set_tick_params(labelsize=10,direction='out')
ax1.xaxis.set_label_position('bottom')
ax1.xaxis.set_ticks_position('bottom')
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=50)
ax1.set_xlabel('Time (Ma)', fontsize=14)


# set y axis
ax1.set_ylim((0.7065, 0.7096)) #ax2.set_ylim((0.704, 0.712)) 
ax1.set_ylabel(r'$^8$'r'$^7$''Sr/'r'$^8$'r'$^6$''Sr',fontsize=16)
ax1.legend((r'$^8$'r'$^7$''Sr/'r'$^8$'r'$^6$''Sr'),bbox_to_anchor=(0.25,.35), loc=2, borderaxespad=0., fontsize=10)


ax2 = ax1.twinx()

ax2.plot(Areas_Lands['Time intervals'],Areas_Lands['A_E-Land (Al+Amo+Ai)']/51*100,'red',
         Areas_Lands['Time intervals'], Areas_Lands['A_T-Land (Al+Amo+Ai+Ama)']/51*100,'blue', linewidth=1.5) #/51*100
#ax2.plot(Areas_Lands['Time intervals'], Areas_Lands['Area_sm']*10,'green', linewidth=1.5)
ax2.set_ylabel('Areas of total land and emerged land [% Earth surface]',fontsize=12)
#ax2.yaxis.set_ticks_position('left')
#ax1.yaxis.set_ticks_position('right')
ax1.yaxis.tick_right()
#ax1.yaxis.set_tick_params(labelsize=12,direction='out')
ax1.yaxis.set_label_position("right")
ax2.yaxis.tick_left()
ax2.yaxis.set_label_position('left')

ax2.legend(('Emerged land','Total land'),bbox_to_anchor=(0.65,.70), loc=2, borderaxespad=0., fontsize=10)
ax1.set_xlim((402,2))
ax1.grid()

plt.show
#plt.savefig('percentages_TLand_ELand.pdf',dpi=600)
#plt.savefig('percentages_TLand_ELand.png',dpi=600)
#plt.savefig('percentages_TLand_ELand.ps',dpi=600)
#plt.savefig('percentages_TLand_ELand.jpg',dpi=600)
# Out:
# <function matplotlib.pyplot.show>

# %%
% matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#plt.figure() #figsize=(12,8)
fig, ax1 = plt.subplots(figsize=(10,6.2))

Sr_data = pd.read_csv('/Users/wenchaocao/Research/34_Paper_Biogeosciences/Nico_data/Dataset.csv')
#Sr_data = pd.read_csv('/Users/wenchaocao/Research/34_Paper_Biogeosciences/Nico_data/sr-data-last-402Ma.dat', delimiter=' ')
Sr_data['Time']
Sr_data['Values']
#ax1.scatter(Sr_data['Time'], Sr_data['Values'],s=40, marker='o', color='lightgrey', edgecolors='grey',alpha=1.)
ax1.plot(Sr_data['Time'], Sr_data['Values'],'green', linewidth=3.5)

# set x axis
ax1.set_xticks(np.hstack((Areas_Lands['Time intervals'][0],Areas_Lands['Time intervals'][1::2]))) #, rotation=50
ax1.xaxis.set_tick_params(labelsize=10,direction='out')
ax1.xaxis.set_label_position('bottom')
ax1.xaxis.set_ticks_position('bottom')
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=50)
ax1.set_xlabel('Time (Ma)', fontsize=14)


# set y axis
ax1.set_ylim((0.7095,0.7065)) #ax2.set_ylim((0.704, 0.712)) 
ax1.set_ylabel(r'$^8$'r'$^7$''Sr/'r'$^8$'r'$^6$''Sr',fontsize=16)
#ax1.legend((r'$^8$'r'$^7$''Sr/'r'$^8$'r'$^6$''Sr'),bbox_to_anchor=(0.25,.35), loc=2, borderaxespad=0., fontsize=10)

ax1.set_xlim((402,2))
ax1.grid()

plt.show
#plt.savefig('percentages_TLand_ELand.pdf',dpi=600)
plt.savefig('Sr.png',dpi=600)
#plt.savefig('percentages_TLand_ELand.ps',dpi=600)
#plt.savefig('percentages_TLand_ELand.jpg',dpi=600)
